# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
# import dataset

df = pd.read_csv('D:\\DS\\Probability Exam\\insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# ideally a normal BMI is somewhere between 18.5 and 24.9
# let's count the probability of someone is overweight given they're a smoker
# which the probability notation will perhaps look like this:

# %% [markdown]
# ![Screenshot%202023-09-06%20202736.png](attachment:Screenshot%202023-09-06%20202736.png)

# %%
# data filter to set up the overweight & smoker union
filter_data = (df["bmi"] > 24.9) & (df["smoker"] == "yes")
p_overweight_smoker = df[filter_df]["smoker"].count()

# counting data on smokers
p_smoker = df[df['smoker']=='yes']['bmi'].count()

# result
result = (p_overweight_smoker/p_smoker * 100).round(1)
print(f'{result} %')
# Out:
# 79.9 %

# %%
# high probability it seems

# %%
# now assuming female are less likely to smoke
# let's see the chances of someone a smoker given the fact they're a male

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# data filter to set up the male and smoker
filter_df_1 = (df["sex"] == 'male') & (df["smoker"] == "yes")
p_smoker_male = df[filter_df_1]["smoker"].count()

# result
result_1 = (p_smoker_male/p_smoker * 100).round(1)
print(f'{result_1} %')
# Out:
# 58.0 %

# %%
# more than 50:50 chances

# %%
# now let's take a look if they're overweight if they're 35 years above

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# data filter to set up the overweight and 35 years +
filter_df_2 = (df["age"] > 35) & (df["bmi"] > 24.9)
p_overweight_old = df[filter_df_2]["age"].count()

# counting data on age
p_old = df[df['age'] > 35]['age'].count()

# result
result_2 = (p_overweight_old/p_old * 100).round(1)
print(f'{result_2} %')
# Out:
# 84.7 %

# %%
# extra consideration should be given if there is an insurance applicants age 35 and above
